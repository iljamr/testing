# %% [markdown]
# # Test Notebook
# This is a notebook for testing if this is a good way of working

# %%
import matplotlib.pyplot as plt
import numpy as np

# Generate some sample data
x = np.linspace(0, 10, 100)
y1 = np.sin(x)
y2 = np.cos(x)
y3 = np.tan(x)
y4 = np.exp(x)
y5 = np.log(x)

# Plot the curves
plt.plot(x, y1, label='sin(x)')
plt.plot(x, y2, label='cos(x)')
plt.plot(x, y3, label='tan(x)')
plt.plot(x, y4, label='exp(x)')
plt.plot(x, y5, label='log(x)')

# Add labels and legend
plt.xlabel('x')
plt.ylabel('y')
plt.legend()

# Show the plot
plt.show()
# Out:
# /tmp/ipykernel_1322/2664023063.py:10: RuntimeWarning: divide by zero encountered in log
#   y5 = np.log(x)
