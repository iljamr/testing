# %% [markdown]
# # Create Folder Structure

# %%
import pathlib
import os

# %load_ext dotenv
# %dotenv

data_path = pathlib.Path(os.environ["DATA_PATH"])

SRC_DIR_VELODYNE = data_path / "kitti/SemanticKITTI/data_velodyne/sequences"
SRC_DIR_CALIB_TIMES = data_path / "kitti/SemanticKITTI/data_calib_times/sequences"
SRC_DIR_LABLE_POSE = data_path / "kitti/SemanticKITTI/data_lable_poses/sequences"


def valid_directories(src_dir1: str, src_dir2: str, src_dir3: str, dest_dir: str):
    src_dir1 = pathlib.Path(src_dir1)
    src_dir2 = pathlib.Path(src_dir2)
    src_dir3 = pathlib.Path(src_dir3)
    dest_dir = pathlib.Path(dest_dir)

    assert src_dir1.name == "sequences"
    assert src_dir2.name == "sequences"
    assert src_dir3.name == "sequences"
    assert dest_dir.name == "sequences"

    dest_dir.mkdir(parents=True, exist_ok=True)

    for dir in (src_dir1, src_dir2, src_dir3):
        for ds_store_file in dir.glob("**/.DS_Store"):
            ds_store_file.unlink()

    sequences = zip(
        sorted(src_dir1.iterdir()),
        sorted(src_dir2.iterdir()),
        sorted(src_dir3.iterdir()),
    )

    return sequences, dest_dir

# %% [markdown]
# ## MotionBEV
#
# According to the documentation, the structure should look like this:
#
# ```
# path_to_KITTI/
# ├──sequences
#     ├── 00/
#     │   ├── calib.txt   # Calibration file.
#     │   ├── poses.txt   # Odometry poses.
#     │   ├── velodyne/	# Unzip from KITTI Odometry Benchmark Velodyne point clouds.
#     |   |	├── 000000.bin
#     |   |	├── 000001.bin
#     |   |	└── ...
#     │   └── labels/ 	# Unzip from SemanticKITTI label data.
#     |       ├── 000000.label
#     |       ├── 000001.label
#     |       └── ...
#     ├── ...
#     └── 21/
#     └── ...
# ```

# %%
def create_symbolic_links(
    dest_dir: str,
    src_dir_velodyne: str = SRC_DIR_VELODYNE,
    src_dir_calib_times: str = SRC_DIR_CALIB_TIMES,
    src_dir_lable_pose: str = SRC_DIR_LABLE_POSE,
):
    sequences, dest_dir = valid_directories(
        src_dir1=src_dir_velodyne,
        src_dir2=src_dir_calib_times,
        src_dir3=src_dir_lable_pose,
        dest_dir=dest_dir,
    )

    for i, (velodyne, calib_times, label_pose) in enumerate(sequences):
        number = f"{i:02}"
        error_msg = lambda x: f"Should be: {number} is {x.name}"
        assert velodyne.name == number, error_msg(velodyne)
        assert calib_times.name == number, error_msg(calib_times)
        assert label_pose.name == number, error_msg(label_pose)

        new_dir = dest_dir / number
        new_dir.mkdir(parents=True, exist_ok=True)

        for dirs in [velodyne, calib_times, label_pose]:
            print(f'{"=" * 100}\nCreating symbolic links for files in: {dirs}')
            for entry in dirs.iterdir():
                link_name = new_dir / entry.name
                if link_name.exists():
                    print(f"\tFile {link_name} already exists, skipping")
                    continue

                print(f"\tFile {link_name} does not exist, creating")
                link_name.symlink_to(entry, target_is_directory=entry.is_dir())


DEST_DIR_MOTIONBEV = data_path / "kitti/SemanticKITTI/symlinks/motionbev/sequences"

create_symbolic_links(dest_dir=DEST_DIR_MOTIONBEV)
# Out:
# ====================================================================================================
# Creating symbolic links for files in: /home/vscode/data/kitti/SemanticKITTI/data_velodyne/sequences/00
# 	File /home/vscode/data/kitti/SemanticKITTI/symlinks/motionbev/sequences/00/velodyne does not exist, creating
# ====================================================================================================
# Creating symbolic links for files in: /home/vscode/data/kitti/SemanticKITTI/data_calib_times/sequences/00
# 	File /home/vscode/data/kitti/SemanticKITTI/symlinks/motionbev/sequences/00/calib.txt does not exist, creating
# 	File /home/vscode/data/kitti/SemanticKITTI/symlinks/motionbev/sequences/00/times.txt does not exist, creating
# ====================================================================================================
# Creating symbolic links for files in: /home/vscode/data/kitti/SemanticKITTI/data_lable_poses/sequences/00
# 	File /home/vscode/data/kitti/SemanticKITTI/symlinks/motionbev/sequences/00/poses.txt does not exist, creating
# 	File /home/vscode/data/kitti/SemanticKITTI/symlinks/motionbev/sequences/00/labels does not exist, creating
# ====================================================================================================
# Creating symbolic links for files in: /home/vscode/data/kitti/SemanticKITTI/data_velodyne/sequences/01
# 	File /home/vscode/data/kitti/SemanticKITTI/symlinks/motionbev/sequences/01/velodyne does not exist, creating
# ====================================================================================================
# Creating symbolic links for files in: /home/vscode/data/kitti/SemanticKITTI/data_calib_times/sequences/01
# 	File /home/vscode/data/kitti/SemanticKITTI/symlinks/motionbev/sequences/01/calib.txt does not exist, creating
# 	File /home/vscode/data/kitti/SemanticKITTI/symlinks/motionbev/sequences/01/times.txt does not exist, creating
# ====================================================================================================
# Creating symbolic links for files in: /home/vscode/data/kitti/SemanticKITTI/data_lable_poses/sequences/01
# 	File /home/vscode/data/kitti/SemanticKITTI/symlinks/motionbev/sequences/01/poses.txt does not exist, creating
# 	File /home/vscode/data/kitti/SemanticKITTI/symlinks/motionbev/sequences/01/labels does not exist, creating
# ====================================================================================================
# Creating symbolic links for files in: /home/vscode/data/kitti/SemanticKITTI/data_velodyne/sequences/02
# 	File /home/vscode/data/kitti/SemanticKITTI/symlinks/motionbev/sequences/02/velodyne does not exist, creating
# ====================================================================================================
# Creating symbolic links for files in: /home/vscode/data/kitti/SemanticKITTI/data_calib_times/sequences/02
# 	File /home/vscode/data/kitti/SemanticKITTI/symlinks/motionbev/sequences/02/calib.txt does not exist, creating
# 	File /home/vscode/data/kitti/SemanticKITTI/symlinks/motionbev/sequences/02/times.txt does not exist, creating
# ====================================================================================================
# Creating symbolic links for files in: /home/vscode/data/kitti/SemanticKITTI/data_lable_poses/sequences/02
# 	File /home/vscode/data/kitti/SemanticKITTI/symlinks/motionbev/sequences/02/poses.txt does not exist, creating
# 	File /home/vscode/data/kitti/SemanticKITTI/symlinks/motionbev/sequences/02/labels does not exist, creating
# ====================================================================================================
# Creating symbolic links for files in: /home/vscode/data/kitti/SemanticKITTI/data_velodyne/sequences/03
# 	File /home/vscode/data/kitti/SemanticKITTI/symlinks/motionbev/sequences/03/velodyne does not exist, creating
# ====================================================================================================
# Creating symbolic links for files in: /home/vscode/data/kitti/SemanticKITTI/data_calib_times/sequences/03
# 	File /home/vscode/data/kitti/SemanticKITTI/symlinks/motionbev/sequences/03/calib.txt does not exist, creating
# 	File /home/vscode/data/kitti/SemanticKITTI/symlinks/motionbev/sequences/03/times.txt does not exist, creating
# ====================================================================================================
# Creating symbolic links for files in: /home/vscode/data/kitti/SemanticKITTI/data_lable_poses/sequences/03
# 	File /home/vscode/data/kitti/SemanticKITTI/symlinks/motionbev/sequences/03/poses.txt does not exist, creating
# 	File /home/vscode/data/kitti/SemanticKITTI/symlinks/motionbev/sequences/03/labels does not exist, creating
# ====================================================================================================
# Creating symbolic links for files in: /home/vscode/data/kitti/SemanticKITTI/data_velodyne/sequences/04
# 	File /home/vscode/data/kitti/SemanticKITTI/symlinks/motionbev/sequences/04/velodyne does not exist, creating
# ====================================================================================================
# Creating symbolic links for files in: /home/vscode/data/kitti/SemanticKITTI/data_calib_times/sequences/04
# 	File /home/vscode/data/kitti/SemanticKITTI/symlinks/motionbev/sequences/04/calib.txt does not exist, creating
# 	File /home/vscode/data/kitti/SemanticKITTI/symlinks/motionbev/sequences/04/times.txt does not exist, creating
# ====================================================================================================
# Creating symbolic links for files in: /home/vscode/data/kitti/SemanticKITTI/data_lable_poses/sequences/04
# 	File /home/vscode/data/kitti/SemanticKITTI/symlinks/motionbev/sequences/04/poses.txt does not exist, creating
# 	File /home/vscode/data/kitti/SemanticKITTI/symlinks/motionbev/sequences/04/labels does not exist, creating
# ====================================================================================================
# Creating symbolic links for files in: /home/vscode/data/kitti/SemanticKITTI/data_velodyne/sequences/05
# 	File /home/vscode/data/kitti/SemanticKITTI/symlinks/motionbev/sequences/05/velodyne does not exist, creating
# ====================================================================================================
# Creating symbolic links for files in: /home/vscode/data/kitti/SemanticKITTI/data_calib_times/sequences/05
# 	File /home/vscode/data/kitti/SemanticKITTI/symlinks/motionbev/sequences/05/calib.txt does not exist, creating
# 	File /home/vscode/data/kitti/SemanticKITTI/symlinks/motionbev/sequences/05/times.txt does not exist, creating
# ====================================================================================================
# Creating symbolic links for files in: /home/vscode/data/kitti/SemanticKITTI/data_lable_poses/sequences/05
# 	File /home/vscode/data/kitti/SemanticKITTI/symlinks/motionbev/sequences/05/poses.txt does not exist, creating
# 	File /home/vscode/data/kitti/SemanticKITTI/symlinks/motionbev/sequences/05/labels does not exist, creating
# ====================================================================================================
# Creating symbolic links for files in: /home/vscode/data/kitti/SemanticKITTI/data_velodyne/sequences/06
# 	File /home/vscode/data/kitti/SemanticKITTI/symlinks/motionbev/sequences/06/velodyne does not exist, creating
# ====================================================================================================
# Creating symbolic links for files in: /home/vscode/data/kitti/SemanticKITTI/data_calib_times/sequences/06
# 	File /home/vscode/data/kitti/SemanticKITTI/symlinks/motionbev/sequences/06/calib.txt does not exist, creating
# 	File /home/vscode/data/kitti/SemanticKITTI/symlinks/motionbev/sequences/06/times.txt does not exist, creating
# ====================================================================================================
# Creating symbolic links for files in: /home/vscode/data/kitti/SemanticKITTI/data_lable_poses/sequences/06
# 	File /home/vscode/data/kitti/SemanticKITTI/symlinks/motionbev/sequences/06/poses.txt does not exist, creating
# 	File /home/vscode/data/kitti/SemanticKITTI/symlinks/motionbev/sequences/06/labels does not exist, creating
# ====================================================================================================
# Creating symbolic links for files in: /home/vscode/data/kitti/SemanticKITTI/data_velodyne/sequences/07
# 	File /home/vscode/data/kitti/SemanticKITTI/symlinks/motionbev/sequences/07/velodyne does not exist, creating
# ====================================================================================================
# Creating symbolic links for files in: /home/vscode/data/kitti/SemanticKITTI/data_calib_times/sequences/07
# 	File /home/vscode/data/kitti/SemanticKITTI/symlinks/motionbev/sequences/07/calib.txt does not exist, creating
# 	File /home/vscode/data/kitti/SemanticKITTI/symlinks/motionbev/sequences/07/times.txt does not exist, creating
# ====================================================================================================
# Creating symbolic links for files in: /home/vscode/data/kitti/SemanticKITTI/data_lable_poses/sequences/07
# 	File /home/vscode/data/kitti/SemanticKITTI/symlinks/motionbev/sequences/07/poses.txt does not exist, creating
# 	File /home/vscode/data/kitti/SemanticKITTI/symlinks/motionbev/sequences/07/labels does not exist, creating
# ====================================================================================================
# Creating symbolic links for files in: /home/vscode/data/kitti/SemanticKITTI/data_velodyne/sequences/08
# 	File /home/vscode/data/kitti/SemanticKITTI/symlinks/motionbev/sequences/08/velodyne does not exist, creating
# ====================================================================================================
# Creating symbolic links for files in: /home/vscode/data/kitti/SemanticKITTI/data_calib_times/sequences/08
# 	File /home/vscode/data/kitti/SemanticKITTI/symlinks/motionbev/sequences/08/calib.txt does not exist, creating
# 	File /home/vscode/data/kitti/SemanticKITTI/symlinks/motionbev/sequences/08/times.txt does not exist, creating
# ====================================================================================================
# Creating symbolic links for files in: /home/vscode/data/kitti/SemanticKITTI/data_lable_poses/sequences/08
# 	File /home/vscode/data/kitti/SemanticKITTI/symlinks/motionbev/sequences/08/poses.txt does not exist, creating
# 	File /home/vscode/data/kitti/SemanticKITTI/symlinks/motionbev/sequences/08/labels does not exist, creating
# ====================================================================================================
# Creating symbolic links for files in: /home/vscode/data/kitti/SemanticKITTI/data_velodyne/sequences/09
# 	File /home/vscode/data/kitti/SemanticKITTI/symlinks/motionbev/sequences/09/velodyne does not exist, creating
# ====================================================================================================
# Creating symbolic links for files in: /home/vscode/data/kitti/SemanticKITTI/data_calib_times/sequences/09
# 	File /home/vscode/data/kitti/SemanticKITTI/symlinks/motionbev/sequences/09/calib.txt does not exist, creating
# 	File /home/vscode/data/kitti/SemanticKITTI/symlinks/motionbev/sequences/09/times.txt does not exist, creating
# ====================================================================================================
# Creating symbolic links for files in: /home/vscode/data/kitti/SemanticKITTI/data_lable_poses/sequences/09
# 	File /home/vscode/data/kitti/SemanticKITTI/symlinks/motionbev/sequences/09/poses.txt does not exist, creating
# 	File /home/vscode/data/kitti/SemanticKITTI/symlinks/motionbev/sequences/09/labels does not exist, creating
# ====================================================================================================
# Creating symbolic links for files in: /home/vscode/data/kitti/SemanticKITTI/data_velodyne/sequences/10
# 	File /home/vscode/data/kitti/SemanticKITTI/symlinks/motionbev/sequences/10/velodyne does not exist, creating
# ====================================================================================================
# Creating symbolic links for files in: /home/vscode/data/kitti/SemanticKITTI/data_calib_times/sequences/10
# 	File /home/vscode/data/kitti/SemanticKITTI/symlinks/motionbev/sequences/10/calib.txt does not exist, creating
# 	File /home/vscode/data/kitti/SemanticKITTI/symlinks/motionbev/sequences/10/times.txt does not exist, creating
# ====================================================================================================
# Creating symbolic links for files in: /home/vscode/data/kitti/SemanticKITTI/data_lable_poses/sequences/10
# 	File /home/vscode/data/kitti/SemanticKITTI/symlinks/motionbev/sequences/10/poses.txt does not exist, creating
# 	File /home/vscode/data/kitti/SemanticKITTI/symlinks/motionbev/sequences/10/labels does not exist, creating
# ====================================================================================================
# Creating symbolic links for files in: /home/vscode/data/kitti/SemanticKITTI/data_velodyne/sequences/11
# 	File /home/vscode/data/kitti/SemanticKITTI/symlinks/motionbev/sequences/11/velodyne does not exist, creating
# ====================================================================================================
# Creating symbolic links for files in: /home/vscode/data/kitti/SemanticKITTI/data_calib_times/sequences/11
# 	File /home/vscode/data/kitti/SemanticKITTI/symlinks/motionbev/sequences/11/calib.txt does not exist, creating
# 	File /home/vscode/data/kitti/SemanticKITTI/symlinks/motionbev/sequences/11/times.txt does not exist, creating
# ====================================================================================================
# Creating symbolic links for files in: /home/vscode/data/kitti/SemanticKITTI/data_lable_poses/sequences/11
# 	File /home/vscode/data/kitti/SemanticKITTI/symlinks/motionbev/sequences/11/poses.txt does not exist, creating
# ====================================================================================================
# Creating symbolic links for files in: /home/vscode/data/kitti/SemanticKITTI/data_velodyne/sequences/12
# 	File /home/vscode/data/kitti/SemanticKITTI/symlinks/motionbev/sequences/12/velodyne does not exist, creating
# ====================================================================================================
# Creating symbolic links for files in: /home/vscode/data/kitti/SemanticKITTI/data_calib_times/sequences/12
# 	File /home/vscode/data/kitti/SemanticKITTI/symlinks/motionbev/sequences/12/calib.txt does not exist, creating
# 	File /home/vscode/data/kitti/SemanticKITTI/symlinks/motionbev/sequences/12/times.txt does not exist, creating
# ====================================================================================================
# Creating symbolic links for files in: /home/vscode/data/kitti/SemanticKITTI/data_lable_poses/sequences/12
# 	File /home/vscode/data/kitti/SemanticKITTI/symlinks/motionbev/sequences/12/poses.txt does not exist, creating
# ====================================================================================================
# Creating symbolic links for files in: /home/vscode/data/kitti/SemanticKITTI/data_velodyne/sequences/13
# 	File /home/vscode/data/kitti/SemanticKITTI/symlinks/motionbev/sequences/13/velodyne does not exist, creating
# ====================================================================================================
# Creating symbolic links for files in: /home/vscode/data/kitti/SemanticKITTI/data_calib_times/sequences/13
# 	File /home/vscode/data/kitti/SemanticKITTI/symlinks/motionbev/sequences/13/calib.txt does not exist, creating
# 	File /home/vscode/data/kitti/SemanticKITTI/symlinks/motionbev/sequences/13/times.txt does not exist, creating
# ====================================================================================================
# Creating symbolic links for files in: /home/vscode/data/kitti/SemanticKITTI/data_lable_poses/sequences/13
# 	File /home/vscode/data/kitti/SemanticKITTI/symlinks/motionbev/sequences/13/poses.txt does not exist, creating
# ====================================================================================================
# Creating symbolic links for files in: /home/vscode/data/kitti/SemanticKITTI/data_velodyne/sequences/14
# 	File /home/vscode/data/kitti/SemanticKITTI/symlinks/motionbev/sequences/14/velodyne does not exist, creating
# ====================================================================================================
# Creating symbolic links for files in: /home/vscode/data/kitti/SemanticKITTI/data_calib_times/sequences/14
# 	File /home/vscode/data/kitti/SemanticKITTI/symlinks/motionbev/sequences/14/calib.txt does not exist, creating
# 	File /home/vscode/data/kitti/SemanticKITTI/symlinks/motionbev/sequences/14/times.txt does not exist, creating
# ====================================================================================================
# Creating symbolic links for files in: /home/vscode/data/kitti/SemanticKITTI/data_lable_poses/sequences/14
# 	File /home/vscode/data/kitti/SemanticKITTI/symlinks/motionbev/sequences/14/poses.txt does not exist, creating
# ====================================================================================================
# Creating symbolic links for files in: /home/vscode/data/kitti/SemanticKITTI/data_velodyne/sequences/15
# 	File /home/vscode/data/kitti/SemanticKITTI/symlinks/motionbev/sequences/15/velodyne does not exist, creating
# ====================================================================================================
# Creating symbolic links for files in: /home/vscode/data/kitti/SemanticKITTI/data_calib_times/sequences/15
# 	File /home/vscode/data/kitti/SemanticKITTI/symlinks/motionbev/sequences/15/calib.txt does not exist, creating
# 	File /home/vscode/data/kitti/SemanticKITTI/symlinks/motionbev/sequences/15/times.txt does not exist, creating
# ====================================================================================================
# Creating symbolic links for files in: /home/vscode/data/kitti/SemanticKITTI/data_lable_poses/sequences/15
# 	File /home/vscode/data/kitti/SemanticKITTI/symlinks/motionbev/sequences/15/poses.txt does not exist, creating
# ====================================================================================================
# Creating symbolic links for files in: /home/vscode/data/kitti/SemanticKITTI/data_velodyne/sequences/16
# 	File /home/vscode/data/kitti/SemanticKITTI/symlinks/motionbev/sequences/16/velodyne does not exist, creating
# ====================================================================================================
# Creating symbolic links for files in: /home/vscode/data/kitti/SemanticKITTI/data_calib_times/sequences/16
# 	File /home/vscode/data/kitti/SemanticKITTI/symlinks/motionbev/sequences/16/calib.txt does not exist, creating
# 	File /home/vscode/data/kitti/SemanticKITTI/symlinks/motionbev/sequences/16/times.txt does not exist, creating
# ====================================================================================================
# Creating symbolic links for files in: /home/vscode/data/kitti/SemanticKITTI/data_lable_poses/sequences/16
# 	File /home/vscode/data/kitti/SemanticKITTI/symlinks/motionbev/sequences/16/poses.txt does not exist, creating
# ====================================================================================================
# Creating symbolic links for files in: /home/vscode/data/kitti/SemanticKITTI/data_velodyne/sequences/17
# 	File /home/vscode/data/kitti/SemanticKITTI/symlinks/motionbev/sequences/17/velodyne does not exist, creating
# ====================================================================================================
# Creating symbolic links for files in: /home/vscode/data/kitti/SemanticKITTI/data_calib_times/sequences/17
# 	File /home/vscode/data/kitti/SemanticKITTI/symlinks/motionbev/sequences/17/calib.txt does not exist, creating
# 	File /home/vscode/data/kitti/SemanticKITTI/symlinks/motionbev/sequences/17/times.txt does not exist, creating
# ====================================================================================================
# Creating symbolic links for files in: /home/vscode/data/kitti/SemanticKITTI/data_lable_poses/sequences/17
# 	File /home/vscode/data/kitti/SemanticKITTI/symlinks/motionbev/sequences/17/poses.txt does not exist, creating
# ====================================================================================================
# Creating symbolic links for files in: /home/vscode/data/kitti/SemanticKITTI/data_velodyne/sequences/18
# 	File /home/vscode/data/kitti/SemanticKITTI/symlinks/motionbev/sequences/18/velodyne does not exist, creating
# ====================================================================================================
# Creating symbolic links for files in: /home/vscode/data/kitti/SemanticKITTI/data_calib_times/sequences/18
# 	File /home/vscode/data/kitti/SemanticKITTI/symlinks/motionbev/sequences/18/calib.txt does not exist, creating
# 	File /home/vscode/data/kitti/SemanticKITTI/symlinks/motionbev/sequences/18/times.txt does not exist, creating
# ====================================================================================================
# Creating symbolic links for files in: /home/vscode/data/kitti/SemanticKITTI/data_lable_poses/sequences/18
# 	File /home/vscode/data/kitti/SemanticKITTI/symlinks/motionbev/sequences/18/poses.txt does not exist, creating
# ====================================================================================================
# Creating symbolic links for files in: /home/vscode/data/kitti/SemanticKITTI/data_velodyne/sequences/19
# 	File /home/vscode/data/kitti/SemanticKITTI/symlinks/motionbev/sequences/19/velodyne does not exist, creating
# ====================================================================================================
# Creating symbolic links for files in: /home/vscode/data/kitti/SemanticKITTI/data_calib_times/sequences/19
# 	File /home/vscode/data/kitti/SemanticKITTI/symlinks/motionbev/sequences/19/calib.txt does not exist, creating
# 	File /home/vscode/data/kitti/SemanticKITTI/symlinks/motionbev/sequences/19/times.txt does not exist, creating
# ====================================================================================================
# Creating symbolic links for files in: /home/vscode/data/kitti/SemanticKITTI/data_lable_poses/sequences/19
# 	File /home/vscode/data/kitti/SemanticKITTI/symlinks/motionbev/sequences/19/poses.txt does not exist, creating
# ====================================================================================================
# Creating symbolic links for files in: /home/vscode/data/kitti/SemanticKITTI/data_velodyne/sequences/20
# 	File /home/vscode/data/kitti/SemanticKITTI/symlinks/motionbev/sequences/20/velodyne does not exist, creating
# ====================================================================================================
# Creating symbolic links for files in: /home/vscode/data/kitti/SemanticKITTI/data_calib_times/sequences/20
# 	File /home/vscode/data/kitti/SemanticKITTI/symlinks/motionbev/sequences/20/calib.txt does not exist, creating
# 	File /home/vscode/data/kitti/SemanticKITTI/symlinks/motionbev/sequences/20/times.txt does not exist, creating
# ====================================================================================================
# Creating symbolic links for files in: /home/vscode/data/kitti/SemanticKITTI/data_lable_poses/sequences/20
# 	File /home/vscode/data/kitti/SemanticKITTI/symlinks/motionbev/sequences/20/poses.txt does not exist, creating
# ====================================================================================================
# Creating symbolic links for files in: /home/vscode/data/kitti/SemanticKITTI/data_velodyne/sequences/21
# 	File /home/vscode/data/kitti/SemanticKITTI/symlinks/motionbev/sequences/21/velodyne does not exist, creating
# ====================================================================================================
# Creating symbolic links for files in: /home/vscode/data/kitti/SemanticKITTI/data_calib_times/sequences/21
# 	File /home/vscode/data/kitti/SemanticKITTI/symlinks/motionbev/sequences/21/calib.txt does not exist, creating
# 	File /home/vscode/data/kitti/SemanticKITTI/symlinks/motionbev/sequences/21/times.txt does not exist, creating
# ====================================================================================================
# Creating symbolic links for files in: /home/vscode/data/kitti/SemanticKITTI/data_lable_poses/sequences/21
# 	File /home/vscode/data/kitti/SemanticKITTI/symlinks/motionbev/sequences/21/poses.txt does not exist, creating

# %%
import directory_tree

directory_tree.display_tree(DEST_DIR_MOTIONBEV, max_depth=2)
# Out:
# sequences/
# ├── 00/
# │   ├── calib.txt
# │   ├── labels/
# │   ├── poses.txt
# │   ├── times.txt
# │   └── velodyne/
# ├── 01/
# │   ├── calib.txt
# │   ├── labels/
# │   ├── poses.txt
# │   ├── times.txt
# │   └── velodyne/
# ├── 02/
# │   ├── calib.txt
# │   ├── labels/
# │   ├── poses.txt
# │   ├── times.txt
# │   └── velodyne/
# ├── 03/
# │   ├── calib.txt
# │   ├── labels/
# │   ├── poses.txt
# │   ├── times.txt
# │   └── velodyne/
# ├── 04/
# │   ├── calib.txt
# │   ├── labels/
# │   ├── poses.txt
# │   ├── times.txt
# │   └── velodyne/
# ├── 05/
# │   ├── calib.txt
# │   ├── labels/
# │   ├── poses.txt
# │   ├── times.txt
# │   └── velodyne/
# ├── 06/
# │   ├── calib.txt
# │   ├── labels/
# │   ├── poses.txt
# │   ├── times.txt
# │   └── velodyne/
# ├── 07/
# │   ├── calib.txt
# │   ├── labels/
# │   ├── poses.txt
# │   ├── times.txt
# │   └── velodyne/
# ├── 08/
# │   ├── calib.txt
# │   ├── labels/
# │   ├── poses.txt
# │   ├── times.txt
# │   └── velodyne/
# ├── 09/
# │   ├── calib.txt
# │   ├── labels/
# │   ├── poses.txt
# │   ├── times.txt
# │   └── velodyne/
# ├── 10/
# │   ├── calib.txt
# │   ├── labels/
# │   ├── poses.txt
# │   ├── times.txt
# │   └── velodyne/
# ├── 11/
# │   ├── calib.txt
# │   ├── poses.txt
# │   ├── times.txt
# │   └── velodyne/
# ├── 12/
# │   ├── calib.txt
# │   ├── poses.txt
# │   ├── times.txt
# │   └── velodyne/
# ├── 13/
# │   ├── calib.txt
# │   ├── poses.txt
# │   ├── times.txt
# │   └── velodyne/
# ├── 14/
# │   ├── calib.txt
# │   ├── poses.txt
# │   ├── times.txt
# │   └── velodyne/
# ├── 15/
# │   ├── calib.txt
# │   ├── poses.txt
# │   ├── times.txt
# │   └── velodyne/
# ├── 16/
# │   ├── calib.txt
# │   ├── poses.txt
# │   ├── times.txt
# │   └── velodyne/
# ├── 17/
# │   ├── calib.txt
# │   ├── poses.txt
# │   ├── times.txt
# │   └── velodyne/
# ├── 18/
# │   ├── calib.txt
# │   ├── poses.txt
# │   ├── times.txt
# │   └── velodyne/
# ├── 19/
# │   ├── calib.txt
# │   ├── poses.txt
# │   ├── times.txt
# │   └── velodyne/
# ├── 20/
# │   ├── calib.txt
# │   ├── poses.txt
# │   ├── times.txt
# │   └── velodyne/
# └── 21/
#     ├── calib.txt
#     ├── poses.txt
#     ├── times.txt
#     └── velodyne/
